# %%
import pandas as pd
import numpy as np


data = pd.read_csv('2017_jun_final.csv')
data.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
# 3                               400   Одесса      до 200 человек  ...
# 4                               500   Другой       до 10 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# 1        True       выше среднего                        Веб-разработка
# 2       False             средний  Веб-разработка,Корпоративные системы
# 3       False       ниже среднего   Desktop Applications,Веб-разработка
# 4       False             средний   Desktop Applications,Веб-разработка
#
#        Дата.заполнения                                         User.Agent  \
# 0  12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2  12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3  12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4  12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
#
#     exp current_job_exp salary Валюта  cls
# 0   0.5             0.5    400    NaN   QA
# 1   0.0             0.0    430    NaN   QA
# 2   4.0             1.0   2500    NaN  DEV
# 3   5.0             4.0   2000    NaN  DEV
# 4  10.0             0.5   4500    NaN  DEV
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (8704, 25)

# %%
data.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %%
data.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Валюта                              8694
# cls                                 1574
# dtype: int64

# %%
data.drop(["Специализация", "Университет", "Предметная.область", "Валюта", "cls"], axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (4854, 20)

# %%
data_new = data.groupby(['Должность']).mean(numeric_only=True)
data_new.head()
# Out:
#                                          N  Зарплата.в.месяц  \
# Должность
# Data Scientist / Data Analyst  1707.000000       2700.000000
# DevOps                         2912.000000       7000.000000
# ERP / CRM                      6713.000000       2000.000000
# HTML coder                     3741.200000        457.000000
# Junior Software Engineer       4410.929688        605.658594
#
#                                Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# Data Scientist / Data Analyst                        300.000000  35.000000
# DevOps                                              5500.000000  29.000000
# ERP / CRM                                           1000.000000  29.000000
# HTML coder                                            70.000000  27.200000
# Junior Software Engineer                             214.321094  24.192187
#
#                                Еще.студент      exp  current_job_exp  \
# Должность
# Data Scientist / Data Analyst      0.00000  1.50000         0.000000
# DevOps                             0.00000  8.00000         0.000000
# ERP / CRM                          1.00000  2.00000         1.000000
# HTML coder                         0.00000  1.70000         0.500000
# Junior Software Engineer           0.34375  1.05918         0.663086
#
#                                     salary
# Должность
# Data Scientist / Data Analyst  2700.000000
# DevOps                         7000.000000
# ERP / CRM                      2000.000000
# HTML coder                      457.000000
# Junior Software Engineer        605.658594

# %%
data_new.agg({'Зарплата.в.месяц' : ['min', 'max']})
# Out:
#      Зарплата.в.месяц
# min             457.0
# max            7000.0

# %%
def fill_avg_salary():
    avg = np.mean(data_new['Зарплата.в.месяц'])
    return(f'%.2f' % avg)
    
avg = data_new.apply(lambda x: fill_avg_salary(), axis=1)
data_new['avg'] = avg
data_new.head()
# Out:
#                                     N  Зарплата.в.месяц  \
# Должность
# Junior Software Engineer  4410.929688        605.658594
# Software Engineer         4187.184041       1678.630074
# Team lead                 6055.500000       3250.000000
# HTML coder                3741.200000        457.000000
# ERP / CRM                 6713.000000       2000.000000
#
#                           Изменение.зарплаты.за.12.месяцев    Возраст  \
# Должность
# Junior Software Engineer                        214.321094  24.192187
# Software Engineer                               448.833026  26.932196
# Team lead                                       500.000000  27.000000
# HTML coder                                       70.000000  27.200000
# ERP / CRM                                      1000.000000  29.000000
#
#                           Еще.студент       exp  current_job_exp       salary  \
# Должность
# Junior Software Engineer     0.343750  1.059180         0.663086   605.658594
# Software Engineer            0.101937  3.444073         1.520065  1678.630074
# Team lead                    0.000000  6.000000         4.500000  3250.000000
# HTML coder                   0.000000  1.700000         0.500000   457.000000
# ERP / CRM                    1.000000  2.000000         1.000000  2000.000000
#
#                               avg
# Должность
# Junior Software Engineer  2907.80
# Software Engineer         2907.80
# Team lead                 2907.80
# HTML coder                2907.80
# ERP / CRM                 2907.80

# %%
data_new.describe()
# Out:
#                  N  Зарплата.в.месяц  Изменение.зарплаты.за.12.месяцев  \
# count    11.000000         11.000000                         11.000000
# mean   4291.576149       2907.803502                        893.804294
# std    1349.655668       1828.363270                       1544.887591
# min    1707.000000        457.000000                         70.000000
# 25%    3917.335648       1839.315037                        364.131019
# 50%    4187.184041       3000.000000                        436.923077
# 75%    4644.026308       3457.136000                        500.000000
# max    6713.000000       7000.000000                       5500.000000
#
#          Возраст  Еще.студент        exp  current_job_exp       salary
# count  11.000000    11.000000  11.000000        11.000000    11.000000
# mean   29.590826     0.139571   4.866590         2.264657  2907.803502
# std     3.351908     0.302879   2.923276         2.229491  1828.363270
# min    24.192187     0.000000   1.059180         0.000000   457.000000
# 25%    27.100000     0.000000   1.850000         0.581543  1839.315037
# 50%    29.000000     0.019444   6.000000         1.520065  3000.000000
# 75%    31.047538     0.074046   7.409000         3.651423  3457.136000
# max    35.000000     1.000000   8.234615         7.000000  7000.000000

# %%
data_new.to_csv('2023_final.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.set(font_scale=1)

data_new.sort_values(by='exp', inplace=True)

plt.plot(
    data_new['exp'],
    data_new['salary'],
)
plt.title("Графік залежності заробітної плати від досвіду роботи", fontsize=12, color="b")
plt.xlabel("Досвід роботи", fontsize=10, color="g")
plt.ylabel("Заробітна плата", fontsize=10, color="g")
# Out:
# Text(0, 0.5, 'Заробітна плата')

# %%
sns.set_style("whitegrid")
data_new.sort_values(by='Возраст', inplace=True)

plt.scatter(
    data_new['Возраст'],
    data_new['salary'],
)
plt.title("Залежность заробітної плати від віку", fontsize=12, color="b")
plt.xlabel("Досвід роботи", fontsize=10, color="g")
plt.ylabel("Заробітна плата", fontsize=10, color="g")
# Out:
# Text(0, 0.5, 'Заробітна плата')

# %%
sns.set_style("darkgrid")
sns.set(font_scale=0.2)
sns.stripplot(x='Должность', y='Зарплата.в.месяц', data=data)
plt.title("Залежність заробітної плати від посади", fontsize=15, color="b")
plt.xlabel("Должность", fontsize=10, color="g")
plt.ylabel("Зарплата.в.месяц", fontsize=10, color="g")
# Out:
# Text(0, 0.5, 'Зарплата.в.месяц')

# %%
sns.set_style("whitegrid")
sns.set(font_scale=0.5)
sns.relplot(x='Общий.опыт.работы', y='Зарплата.в.месяц', kind='scatter', hue='Должность', data=data)
plt.title("Залежність заробітної плати від досвіду роботи по посадах", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Залежність заробітної плати від досвіду роботи по посадах')
